# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from GlauberModel import *

# %%
DisplayData()

# %%
N=1

# %%
PbPb5500GeV=Collider(N,'Pb',5500)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-81fa86347079> in <module>()
# ----> 1 PbPb5500GeV=Collider(N,'Pb',5500)
#
# C:\Users\Crex\Documents\GitHub\PHYS202-S13\SeniorProject\GlauberModel.py in Collider(N, Particle, BeamEnergy)
#     122     a={'C':0,'O':.513,'Al':.519,'S':.61,'Ca':.586,'Ni':.516,'Cu':.596,'W':.535,'Au':.535,'Pb':.546,'U':.6}
#     123     Rp=R[Particle]
# --> 124     b=1.5*Rp*random_sample(N)
#     125     r=arange(0,1.5*Rp+.01,.01)
#     126     Npart=zeros(N,float)
#
# NameError: global name 'random_sample' is not defined

# %%
PlotNuclei(PbPb5500GeV[1],PbPb5500GeV[2],'Pb')

# %%
PlotCollision(N,'Pb',PbPb5500GeV[0],PbPb5500GeV[1],PbPb5500GeV[2],PbPb5500GeV[3],PbPb5500GeV[4],PbPb5500GeV[5],PbPb5500GeV[6],PbPb5500GeV[7])

# %%
AuAu20GeV=Collider(N,'Au',20)

# %%
PlotNuclei(AuAu20GeV[1],AuAu20GeV[2],'Au')

# %%
PlotCollision(N,'Au',AuAu20GeV[0],AuAu20GeV[1],AuAu20GeV[2],AuAu20GeV[3],AuAu20GeV[4],AuAu20GeV[5],AuAu20GeV[6],AuAu20GeV[7])
