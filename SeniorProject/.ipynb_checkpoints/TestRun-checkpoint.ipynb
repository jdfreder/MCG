# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from GlauberModel import *

# %%
DisplayData()

# %%
N=50

# %%
PbPb5500GeV=Collider(N,'Pb',5500)

# %%
PlotNuclei(PbPb5500GeV[1],PbPb5500GeV[2],'Pb')

# %%
PlotCollision(N,'Pb',PbPb5500GeV[0],PbPb5500GeV[1],PbPb5500GeV[2],PbPb5500GeV[3],PbPb5500GeV[4],PbPb5500GeV[5],PbPb5500GeV[6],PbPb5500GeV[7])

# %%
AuAu200GeV=Collider(N,'Au',200)

# %%
PlotNuclei(AuAu200GeV[1],AuAu200GeV[2],'Au')

# %%
PlotCollision(N,'Au',AuAu200GeV[0],AuAu200GeV[1],AuAu200GeV[2],AuAu200GeV[3],AuAu200GeV[4],AuAu200GeV[5],AuAu200GeV[6],AuAu200GeV[7])

# %%
PlotResults(AuAu200GeV[0],AuAu200GeV[3],AuAu200GeV[4])

# %%
print AuAu200GeV[5]
r=AuAu200GeV[5]
# Out:
# 1.20357399321

# %%
A=pi*r**2
print A
# Out:
# 4.550880824
