# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from GlauberModel import *
# Out:
# GlauberModel.py:34: RuntimeWarning: invalid value encountered in log
#   sigma=Z+np.pi*(hbar*c)**2/M**2*(np.log((s)**2/sM))**2+Y1*(sM/(s)**2)**n1-Y2*(sM/(s)**2)**n2
# GlauberModel.py:34: RuntimeWarning: invalid value encountered in power
#   sigma=Z+np.pi*(hbar*c)**2/M**2*(np.log((s)**2/sM))**2+Y1*(sM/(s)**2)**n1-Y2*(sM/(s)**2)**n2

# %%
DisplayData()

# %%
N=50

# %%
PbPb5500GeV=Collider(N,'Pb',5500,False)

# %%
PlotNuclei(PbPb5500GeV[1],PbPb5500GeV[2],'Pb',False)

# %%
PlotCollision(N,'Pb',PbPb5500GeV[0],PbPb5500GeV[1],PbPb5500GeV[2],PbPb5500GeV[3],PbPb5500GeV[4],PbPb5500GeV[5],PbPb5500GeV[6],PbPb5500GeV[7])

# %%
AuAu200GeVF=Collider(N,'Au',200,False)

# %%
PlotNuclei(AuAu200GeVF[1],AuAu200GeVF[2],'Au',False)

# %%
PlotCollision(N,'Au',AuAu200GeVF[0],AuAu200GeVF[1],AuAu200GeVF[2],AuAu200GeVF[3],AuAu200GeVF[4],AuAu200GeVF[5],AuAu200GeVF[6],AuAu200GeVF[7])

# %%
PlotResults(AuAu200GeVF[0],AuAu200GeVF[3],AuAu200GeVF[4])
