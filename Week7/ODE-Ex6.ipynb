# %% [markdown]
# Example 1
# -

# %%
a=-9.8 #m/s^2
n=100
t=10.
v=zeros(n+1,float)
r=zeros(n+1,float)
for i in range(n):
    v[i+1]=v[i]+a*t/n
    r[i+1]=r[i]+v[i]*t/n
#print v[i+1]
print "Euler method:",str(r[i+1])
print "Actual:",str(.5*-9.8*100)
# Out:
# Euler method: -485.1
# Actual: -490.0

# %% [markdown]
# Exercise 1:
# -

# %% [markdown]
# (a)

# %%
x1=arange(0,2.25,.25)
#y[i+1]=y[i]+(x[i]+2*y[i])*x/n
y=zeros(x1.shape,float)
for i in range(len(x1)-1):
    y[i+1]=y[i]+(x1[i]+2*y[i])*(x1[i+1]-x1[i])
print y[4]
# Out:
# 0.515625

# %%
Px=arange(0,2.02,.02)
Py=zeros(Px.shape,float)
for i in range(len(Px)-1):
    Py[i+1]=Py[i]+(Px[i]+2*Py[i])*(Px[i+1]-Px[i])
print Py[50]
# Out:
# 1.02667083657

# %% [markdown]
# (b)

# %%
x=arange(0,2.01,.01)
plot(x,.25*e**(2*x)-.5*x-.25,label='Actual',lw=2)
plot(x1,y,label='Steps of 0.25')
plot(Px,Py,label='Steps of .02')
legend(loc='upper left')

# %% [markdown]
# Steps of .02 gives more accurate results.

# %% [markdown]
# (c)

# %%
#Euler-Cromer
x1=arange(0,2.25,.25)
y=zeros(x1.shape,float)
for i in range(len(x1)-1):
    y[i+1]=y[i]+(x1[i+1]+2*y[i])*(x1[i+1]-x1[i])

# %%
Px=arange(0,2.02,.02)
Py=zeros(Px.shape,float)
for i in range(len(Px)-1):
    Py[i+1]=Py[i]+(Px[i+1]+2*Py[i])*(Px[i+1]-Px[i])

# %%
x=arange(0,2.01,.01)
plot(x,.25*e**(2*x)-.5*x-.25,label='Actual',lw=2)
plot(x1,y,label='Steps of 0.25')
plot(Px,Py,label='Steps of .02')
legend(loc='upper left')

# %%
#plot(x,.25*e**(2*x)-.5*x-.25,label='Actual',lw=2)
plot(x1,.25*e**(2*x1)-.5*x1-.25-y,color='green',label='Error in .25 steps')
plot(Px,.25*e**(2*x2)-.5*x2-.25-Py,color='red',label='Error in .02 steps')
legend(loc='upper left')

# %%
#Midpoint Method
x1=arange(0,2.25,.25)
y=zeros(x1.shape,float)
for i in range(len(x1)-1):
    y[i+1]=y[i]+.5*(x1[i]+2*y[i]+x1[i+1]+2*y[i])*(x1[i+1]-x1[i])

# %%
Px=arange(0,2.02,.02)
Py=zeros(Px.shape,float)
for i in range(len(Px)-1):
    Py[i+1]=Py[i]+.5*(Px[i]+2*Py[i]+Px[i+1]+2*Py[i])*(Px[i+1]-Px[i])

# %%
x=arange(0,2.01,.01)
plot(x,.25*e**(2*x)-.5*x-.25,label='Actual',lw=2)
plot(x1,y,label='Steps of 0.25')
plot(Px,Py,label='Steps of .02')
legend(loc='upper left')

# %%
plot(x1,.25*e**(2*x1)-.5*x1-.25-y,color='green',label='Error in .25 steps')
plot(Px,.25*e**(2*x2)-.5*x2-.25-Py,color='red',label='Error in .02 steps')
legend(loc='upper left')

# %% [markdown]
# The midpoint method with step sizes of .02 gives the most accurate results.

# %% [markdown]
# 2.
# -

# %% [markdown]
# (a)

# %%
print "\t".join(['Projectile', '\t(Angle[Rad],Speed[m/s])', '(Angle[Rad],Speed[m/s])', '(Angle[Rad],Speed[m/s]'])
print "\f".join(['Human Cannonball:','\t(5*18\pi,30.6)','\t\t(1,32.6)','\t\t(1.33,50)'])
print "\f".join(['Golfball:','\t\t(5*18\pi,34.2)','\t\t(1.02,36.9)','\t\t(1.31,60)'])
print "\f".join(['Baseball:','\t\t(5*18\pi,34)','\t\t(1.07,40)','\t\t(1.24,50)'])
# Out:
# Projectile		(Angle[Rad],Speed[m/s])	(Angle[Rad],Speed[m/s])	(Angle[Rad],Speed[m/s]
# Human Cannonball:	(5*18\pi,30.6)		(1,32.6)		(1.33,50)
# Golfball:		(5*18\pi,34.2)		(1.02,36.9)		(1.31,60)
# Baseball:		(5*18\pi,34)		(1.07,40)		(1.24,50)

# %% [markdown]
# (b)
