# %% [markdown]
# Publication ready plot template
# =
# Simple graphing template for matplotlib functions and data plots.
# -

# %% [markdown]
# Line plots

# %%
y = arange(-5,5,.01) #sets y equal to an array of numbers between -5 and 5
E = cosh(y)
p=sinh(y)

# %%
plot(y,E,color="blue",linewidth=2,label="E label")
plot(y,p,color="red",linewidth=2,label="p label")
xlabel("X label",fontsize=14)
ylabel("Y label",fontsize=14)
title("Title",fontsize=20)
legend(loc=4)
grid(True)
ax = gca()
#Remove the spines
ax.spines['right'].set_color('none') 
ax.spines['left'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')

# %% [markdown]
# Subplots

# %%
subplot(211)
title("Title",fontsize=20)
plot(y,E,color="blue",linewidth=2)
ylabel("Y label 1",fontsize=14)
grid(True)
ax = gca()
#Remove the spines
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
subplot(212)
plot(y,p,color="red",linewidth=2)
xlabel("X label",fontsize=14)
ylabel("Y label 2",fontsize=14)
grid(True)
ax = gca()
#Remove the spines
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')

# %% [markdown]
# Scatter Plot

# %%
n = 200
X = random.normal(0,1,n)
Y = random.normal(0,1,n)
plot(X,Y,ls='',marker='.',ms=5)
xlabel("X label",fontsize=14)
ylabel("Y label",fontsize=14)
title("Title",fontsize=20)
grid(True)
ax = gca()
#Remove the spines
ax.spines['right'].set_color('none') 
ax.spines['left'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
